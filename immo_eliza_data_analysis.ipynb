# %% [markdown]
# Step 0 : Import data

# %%
import pandas as pd
import numpy as np

immo = pd.read_csv("data/_properties_data.csv", index_col='id')
immo.head()
# Out:
# C:\Users\mendo\AppData\Local\Temp\ipykernel_16740\3897253848.py:4: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   immo = pd.read_csv("data/_properties_data.csv", index_col='id')
#                                                     URL  Status  \
# id
# 10616805  https://www.immoweb.be/en/classified/10616805     200
# 10616810  https://www.immoweb.be/en/classified/10616810     200
# 10616831  https://www.immoweb.be/en/classified/10616831     200
# 10616813  https://www.immoweb.be/en/classified/10616813     200
# 10616815  https://www.immoweb.be/en/classified/10616815     200
#
#          transactionType transactionSubtype     price             type  \
# id
# 10616805        FOR_SALE        BUY_REGULAR  695000.0        APARTMENT
# 10616810        FOR_SALE        BUY_REGULAR  317500.0        APARTMENT
# 10616831        FOR_SALE        BUY_REGULAR  465000.0        APARTMENT
# 10616813        FOR_SALE        BUY_REGULAR  385000.0        APARTMENT
# 10616815        FOR_SALE        BUY_REGULAR       NaN  APARTMENT_GROUP
#
#                   subtype  country    region         province  ...  \
# id                                                             ...
# 10616805        APARTMENT  Belgium  Flanders    West Flanders  ...
# 10616810        APARTMENT  Belgium  Flanders    East Flanders  ...
# 10616831     GROUND_FLOOR  Belgium  Wallonie  Walloon Brabant  ...
# 10616813        APARTMENT  Belgium  Brussels         Brussels  ...
# 10616815  APARTMENT_GROUP  Belgium  Wallonie       Luxembourg  ...
#
#          toiletCount parkingCountIndoor  parkingCountOutdoor  \
# id
# 10616805         2.0                NaN                  NaN
# 10616810         NaN                1.0                  1.0
# 10616831         2.0               53.0                 53.0
# 10616813         1.0                1.0                  1.0
# 10616815         NaN                NaN                  NaN
#
#          parkingCountClosedBox primaryEnergyConsumptionPerSqm epcScore  \
# id
# 10616805                   NaN                           93.0        A
# 10616810                   NaN                            NaN      NaN
# 10616831                   NaN                           50.0        A
# 10616813                   NaN                            NaN      NaN
# 10616815                   NaN                            NaN      NaN
#
#           hasDoubleGlazing              saleType  \
# id
# 10616805              True                   NaN
# 10616810              True                   NaN
# 10616831              True                   NaN
# 10616813               NaN                   NaN
# 10616815               NaN  NewRealEstateProject
#
#                           creationDate          lastModificationDate
# id
# 10616805  2023-06-07T06:47:04.000+0000  2023-06-29T08:21:22.767+0000
# 10616810  2023-06-07T06:47:54.000+0000  2023-06-29T08:34:19.170+0000
# 10616831  2023-06-07T06:54:05.000+0000  2023-06-29T08:35:00.040+0000
# 10616813  2023-06-07T06:49:00.000+0000  2023-06-29T08:26:25.197+0000
# 10616815  2023-06-07T06:50:47.000+0000  2023-06-29T14:04:26.017+0000
#
# [5 rows x 44 columns]

# %% [markdown]
# Step 1 : Data Cleaning

# %%
#validate numbres (only numbers)
#immo["price"] = immo["price"].astype(int)
immo.select_dtypes(include= np.number)
# Out:
#           Status     price  postalCode  floor  bedroomCount  \
# id
# 10616839     200  265000.0      3200.0    0.0           2.0
# 10616917     200  169000.0      8660.0    0.0           1.0
# 10616910     200  399000.0      3550.0    1.0           2.0
# 10616840     200  265000.0      3200.0    0.0           2.0
# 10616926     200  165000.0      4101.0    0.0           2.0
# ...          ...       ...         ...    ...           ...
# 10616805     200  695000.0      8300.0    1.0           2.0
# 10616810     200  317500.0      9200.0    0.0           3.0
# 10616831     200  465000.0      1420.0    0.0           3.0
# 10616813     200  385000.0      1210.0    1.0           2.0
# 10616815     200       NaN      6810.0    NaN           NaN
#
#           netHabitableSurface  constructionYear  facadeCount  floorCount  \
# id
# 10616839                 90.0            1976.0          4.0         3.0
# 10616917                  NaN               NaN          NaN         NaN
# 10616910                125.0            2013.0          NaN         NaN
# 10616840                 90.0            1976.0          4.0         3.0
# 10616926                 70.0               NaN          NaN         NaN
# ...                       ...               ...          ...         ...
# 10616805                 74.0            2004.0          2.0         4.0
# 10616810                127.0            2022.0          NaN         NaN
# 10616831                130.0            2025.0          2.0         3.0
# 10616813                 85.0            2023.0          2.0         6.0
# 10616815                  NaN               NaN          NaN         NaN
#
#           gardenSurface  terraceSurface  land  bathroomCount  showerRoomCount  \
# id
# 10616839            NaN             NaN   NaN            1.0              1.0
# 10616917            NaN             NaN   NaN            NaN              0.0
# 10616910            NaN            24.0   NaN            1.0              0.0
# 10616840            NaN             NaN   NaN            1.0              1.0
# 10616926           90.0             NaN   NaN            NaN              1.0
# ...                 ...             ...   ...            ...              ...
# 10616805            NaN             4.0   NaN            2.0              0.0
# 10616810            NaN            16.0   NaN            1.0              0.0
# 10616831          154.0            18.0   NaN            2.0              0.0
# 10616813            NaN             8.0   NaN            1.0              1.0
# 10616815            NaN             NaN   NaN            NaN              NaN
#
#           toiletCount  parkingCountIndoor  parkingCountOutdoor  \
# id
# 10616839          1.0                 NaN                  NaN
# 10616917          NaN                 NaN                  NaN
# 10616910          1.0                 1.0                  1.0
# 10616840          1.0                 NaN                  NaN
# 10616926          1.0                 NaN                  NaN
# ...               ...                 ...                  ...
# 10616805          2.0                 NaN                  NaN
# 10616810          NaN                 1.0                  1.0
# 10616831          2.0                53.0                 53.0
# 10616813          1.0                 1.0                  1.0
# 10616815          NaN                 NaN                  NaN
#
#           parkingCountClosedBox  primaryEnergyConsumptionPerSqm
# id
# 10616839                    NaN                           117.0
# 10616917                    NaN                           391.0
# 10616910                    NaN                           142.0
# 10616840                    NaN                           164.0
# 10616926                    NaN                           366.0
# ...                         ...                             ...
# 10616805                    NaN                            93.0
# 10616810                    NaN                             NaN
# 10616831                    NaN                            50.0
# 10616813                    NaN                             NaN
# 10616815                    NaN                             NaN
#
# [19976 rows x 19 columns]
